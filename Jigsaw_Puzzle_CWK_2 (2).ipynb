# %%
# ==========================================
# JIGSAW PUZZLE: CALCULUS & OPTIMISATION
# ==========================================
# Instructions: The code snippets below have been reshuffled from different
# tasks.
# Identify the tasks and rearrange the blocks to create working scripts, one
# script per task, to be executed successfully.
# ==========================================

# --- Fragment A: ?????????????? ---
def gradient_descent(X_b, y, theta, learning_rate=0.01, tolerance=1e-6, max_iterations=1000):
    m = len(y)
    cost_history = []
    for iteration in range(max_iterations):
        predictions = X_b.dot(theta)
        error = predictions - y
        gradients = (2/m) * X_b.T.dot(error)
        theta = theta - learning_rate * gradients

        current_cost = np.mean((predictions - y)**2)
        cost_history.append(current_cost)

        if iteration > 0 and abs(cost_history[-2] - cost_history[-1]) < tolerance:
            break
    return theta, cost_history

# --- Fragment B: Projectile Physics ---
v0 = 20.0
angle_deg = 45.0
g = 9.81
theta_rad = math.radians(angle_deg)

height_max = (v0**2 * (math.sin(theta_rad)**2)) / (2 * g)
range_dist = (v0**2 * math.sin(2 * theta_rad)) / g
print(f"Max Height: {height_max:.2f}m, Range: {range_dist:.2f}m")

# --- Fragment C: ???????????? ---
plt.figure(figsize=(14, 5))
degrees = [1, 4, 15]

for i, degree in enumerate(degrees):
    ax = plt.subplot(1, 3, i + 1)
    pipeline = Pipeline([
        ("poly", PolynomialFeatures(degree=degree, include_bias=False)),
        ("linear", LinearRegression())
    ])
    pipeline.fit(X_synth[:, np.newaxis], y_synth)

    # Plotting logic
    X_test = np.linspace(0, 1, 100)
    plt.plot(X_test, true_fun(X_test), label="True", color="lime")
    plt.plot(X_test, pipeline.predict(X_test[:, np.newaxis]), label="Model")
    plt.scatter(X_synth, y_synth, edgecolor="b", s=20)
    plt.title(f"Degree {degree}")

# --- Fragment D: Imports ---
import math
import numpy as np
import sympy as sp
import matplotlib.pyplot as plt
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

# --- Fragment E: ???????????? ---
critical_points = sp.solve(f_prime, x)
print(f"Critical Points found at x = {critical_points}")

for point in critical_points:
    concavity = f_double_prime.subs(x, point)
    if concavity > 0:
        print(f"x={point} is a Local Minimum")
    elif concavity < 0:
        print(f"x={point} is a Local Maximum")
    else:
        print(f"x={point} is a Saddle Point")

# --- Fragment F: Data Generation for GD ---
np.random.seed(42)
X_gd = 2 * np.random.rand(100, 1)
y_gd = 4 + 3 * X_gd + np.random.randn(100, 1)
X_b_gd = np.c_[np.ones((100, 1)), X_gd]

# --- Fragment G: Derivative Calculation ---
x = sp.symbols('x')
f = x**3 - 6*x**2 + 9*x + 2
f_prime = sp.diff(f, x)
f_double_prime = sp.diff(f_prime, x)

# --- Fragment H: ?????????? ---
theta_initial = np.random.randn(2, 1)
theta_final, costs = gradient_descent(X_b_gd, y_gd, theta_initial)
print(f"GD Result: Intercept={theta_final[0]}, Slope={theta_final[1]}")

# --- Fragment I: ????????? ---
n_samples = 30
true_fun = lambda X: np.cos(1.5 * np.pi * X)
X_synth = np.sort(np.random.rand(n_samples))
y_synth = true_fun(X_synth) + np.random.randn(n_samples) * 0.1

# --- Fragment J: Final Plot Show ---
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-113163281.py in <cell line: 0>()
#      28 angle_deg = 45.0
#      29 g = 9.81
# ---> 30 theta_rad = math.radians(angle_deg)
#      31
#      32 height_max = (v0**2 * (math.sin(theta_rad)**2)) / (2 * g)
#
# NameError: name 'math' is not defined
